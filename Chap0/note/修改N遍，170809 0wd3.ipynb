# %% [markdown]
# ## 170809 0wd3
#
# ## 今天一共花了 2 小时学习编程，主要练习猜数字小游戏：
#
#
# ## 复盘：猜数字小游戏的coding经历
#
# - 看过卡片中的视频，知道了小游戏成品后的结果，开始琢磨如何实现它。
# - 第一步先写注释和关键词
#   - 随机数，循环，条件语句，N多个print，次数递减，判断是否为数字
# - 第二步考虑如何实现随机数
#   - random是随机的意思，所以查官方文档输入关键词，查到了random的用法，默认为float，但是我想要int，所以找到randint函数。
#   - randint函数写完后发现出错，产生不了随机数，显示没有定义变量randint。
#   - 继续看官方文档，看到范例中有import，顿时明白了，需要引入random模块
# - 第三步输入所有视频中出现过的中文字。
#   - 测试一堆print，发现中文显示错误，结果是需要添加utf-8。
#   - 设置input。
# - 第四步开始琢磨逻辑关系。
#   - 先把if，elif，else这些搞定。
#   - 循坏最开始钻了很长时间牛角尖，鼓捣for in循环，写完后，阅读都有障碍。
#   - 果断换成while循环，从阅读源代码的角度看没有障碍了。
# - 第五步开始考虑判断是否为数字，考虑递减
#   - 查官方文档，输入digit关键词，找到isdigit函数，发现返回true代表是数字，可用在猜数字小游戏中做判断。
#   - 递减用--通过不了，只能改用`i = i - 1`
# - 第六步，运行
#   - 立刻出错，控制台不出现错误反馈，但是也没有任何反应。立即想到没有call函数。
#   - 继续出错，拼写错误，times写成了time
#   - 继续出错，== 写成了 =
#   - 还是错，str与number不能比较大小，立即对输入的值加了`int()`
#   - 接着错，
#   - 依然错，答对答案不出现结果，出错为str和number不能相加，立即对随机数加了`str()`
#   - 还错，无法出现和视频中一摸一样的结果，或者出现“还剩0次”的提醒，或者打印很多次“结束”，依然可以进行下一步。立刻反思，又增添了if判断次数是否为0。
#   - 依旧错，缩进有问题，改了一行，下一行继续显示缩进错误。索性都减空格，减到上一行后打回车。
# - 第七步，增加选择游戏难度，增加多个游戏玩家。
#   - if语句可以选择游戏，未按照要求输入直接退出。
#   - 增加多个玩家需要用到循环，第一印象就是一直循环，认为终止。所以用`while true`，结果出错，true没有被定义，所以立刻意识到关键词错误，改为`while Ture`，然后print里说明输入名字，退出用ctrl+c。
#
# ## 初步掌握：
#
# - 导入函数模块，循环，调用函数，中文utf-8设置，格式转换
#
# ## 改进计划：避免大坑
#
# - 做猜数字小游戏总结出了几个大坑。
# - 一定要做一部分测试一部分，千万不要写一大段再运行。要局部顺利，再扩展。
# - 一定不要tab缩进，要打空格，不然就是全部行缩进错误，非常头疼。
# - 注意拼写错误，单词拼写，符号拼写。
# - 明天开始琢磨高难度的小游戏，然后上传作业，听开学直播。

# %%
# coding=utf-8

from random import randint

def guess_number():
	answer = randint(0, 20)
	times = 10
	while times > 0:
		guess = input ("请输入数字：")
		if guess.isdigit():
			if int(guess) > answer:
				print ("比正确答案大了")
				times = times - 1
				if times == 0:
					print ("结束")
				else:
					print ("你还有 %d 次机会可以输入" % times)
			elif int(guess) < answer:
				print ("比正确答案小了")
				times = times - 1
				if times == 0:
					print ("结束")
				else:
					print ("你还有 %d 次机会可以输入" % times)
			else:
				print ("答案正确，答案就是 " + str(answer))
				print ("结束")
				break
		else:
			print ("请确保你输入的是数字")

while True:
	print ("请输入玩家的名字, 输入CTRL+C退出游戏")
	input ()
	level = input ("输入你想玩的游戏级别，1 或 2: ")
	if level == "1":
		guess_number()
	elif level == "2":
		print ("正在开发中")
	else:
		print ("不按要求玩，拜拜！")
# Out:
# 请输入玩家的名字, 输入CTRL+C退出游戏
# 1
# 输入你想玩的游戏级别，1 或 2: 1
# 请输入数字：0
# 比正确答案小了
# 你还有 9 次机会可以输入
# 请输入数字：14
# 比正确答案小了
# 你还有 8 次机会可以输入
# 请输入数字：16
# 比正确答案小了
# 你还有 7 次机会可以输入
# 请输入数字：17
# 比正确答案小了
# 你还有 6 次机会可以输入
# 请输入数字：18
# 比正确答案小了
# 你还有 5 次机会可以输入
# 请输入数字：19
# 答案正确，答案就是 19
# 结束
# 请输入玩家的名字, 输入CTRL+C退出游戏
# ctrl+c
# 输入你想玩的游戏级别，1 或 2: exit（）
# 不按要求玩，拜拜！
# 请输入玩家的名字, 输入CTRL+C退出游戏
# ctrl+c
# 输入你想玩的游戏级别，1 或 2: CTRL+C
# 不按要求玩，拜拜！
# 请输入玩家的名字, 输入CTRL+C退出游戏
# 又遇到坑，结束不了，只能再控制台结束。。。
